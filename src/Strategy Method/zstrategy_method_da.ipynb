# %% [markdown]
# # Strategy Method Data Analysis Showcase

# %%
from constants import conditional_investment_x_values, conditional_investment_list, fgf_distribution, fgq_distrubtion
from sm_data_clean_utils import sm_reading_and_cleaning, sm_merge_game_and_instrucs
from strategy_method_utils import strategy_method_analysis
from infographic_utils import gen_sm_infographic

# %% [markdown]
# ### Sessions

# %%
smdf, all_sessions_player_type_dict, player_types_per_session_list, stat_test_dict, unconditional_dict, conditional_dict = strategy_method_analysis(
    '/Users/aaronberman/Desktop/DA_4_MGPGG/ToDate/StrategyMethod_2023-09-26.csv', conditional_investment_x_values, conditional_investment_list, fgf_distribution, fgq_distrubtion,
    1)
# Out:
# /Users/aaronberman/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /Users/aaronberman/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:4484: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())

# %%
smdf
# Out:
#      participant.id_in_session participant.code  participant.payoff  \
# 0                            1         znlu9jpg               841.0
# 1                            2         ntsf9cu5              1157.0
# 2                            3         4hnzonph              1210.0
# 3                            4         wye0azrj              1059.0
# 4                            5         zq928mn2              1049.0
# ..                         ...              ...                 ...
# 187                         12         r5gp08hr               624.0
# 188                         13         cbj3ehdm               991.0
# 189                         14         nle6hs8b               864.0
# 190                         15         nyszjmr9               860.0
# 191                         16         ztrzsad5               860.0
#
#      player.id_in_group  player.payoff  player.unconditional_investment  \
# 0                     1          270.0                             15.0
# ...

# %%
all_sessions_player_type_dict
# Out:
# {'num_players': 192,
#  'num_free_rider': 14,
#  'num_conditional_cooperators': 127,
#  'num_hump_shaped': 29,
#  'num_other': 33}

# %%
player_types_per_session_list
# Out:
# [{'num_players': 16,
#   'num_free_rider': 1,
#   'num_conditional_cooperators': 13,
#   'num_hump_shaped': 1,
#   'num_other': 2},
#  {'num_players': 16,
#   'num_free_rider': 1,
#   'num_conditional_cooperators': 12,
#   'num_hump_shaped': 0,
#   'num_other': 3},
#  {'num_players': 16,
#   'num_free_rider': 2,
#   'num_conditional_cooperators': 10,
#   'num_hump_shaped': 2,
#   'num_other': 3},
#  {'num_players': 16,
#   'num_free_rider': 2,
#   'num_conditional_cooperators': 11,
#   'num_hump_shaped': 3,
#   'num_other': 2},
#  {'num_players': 16,
#   'num_free_rider': 0,
#   'num_conditional_cooperators': 12,
#   'num_hump_shaped': 1,
#   'num_other': 4},
#  {'num_players': 16,
#   'num_free_rider': 0,
#   'num_conditional_cooperators': 11,
#   'num_hump_shaped': 2,
#   'num_other': 3},
#  {'num_players': 16,
#   'num_free_rider': 2,
#   'num_conditional_cooperators': 10,
#   'num_hump_shaped': 4,
#   'num_other': 3},
#  {'num_players': 16,
#   'num_free_rider': 2,
# ...

# %%
stat_test_dict
# Out:
# {'fisher_p_val': -inf,
#  'fgf_chi2': 20.13663214732453,
#  'fgf_p_val': 0.00015902687771932148,
#  'fgf_dof': 3,
#  'fgf_ex': array([[ 22.1902834 , 122.45748988,  28.76518219,  29.58704453],
#         [  4.8097166 ,  26.54251012,   6.23481781,   6.41295547]]),
#  'fgq_chi2': 19.185477685124894,
#  'fgq_p_val': 0.00025028679965944295,
#  'fgq_dof': 3,
#  'fgq_ex': array([[ 27.2244898 , 120.73469388,  27.2244898 ,  27.81632653],
#         [ 18.7755102 ,  83.26530612,  18.7755102 ,  19.18367347]])}

# %%
unconditional_dict
# Out:
# {'all_players': 8.46875,
#  'free_riders': 3.357142857142857,
#  'conditional_cooperators': 9.68503937007874,
#  'hump_shaped': 6.586206896551724,
#  'others': 7.515151515151516}

# %%
conditional_dict
# Out:
# {'all_players': player.conditional_investment_0      1.437500
#  player.conditional_investment_1      2.057292
#  player.conditional_investment_2      2.572917
#  player.conditional_investment_3      2.953125
#  player.conditional_investment_4      3.494792
#  player.conditional_investment_5      3.916667
#  player.conditional_investment_6      4.546875
#  player.conditional_investment_7      5.281250
#  player.conditional_investment_8      5.677083
#  player.conditional_investment_9      6.161458
#  player.conditional_investment_10     7.161458
#  player.conditional_investment_11     7.562500
#  player.conditional_investment_12     7.942708
#  player.conditional_investment_13     8.312500
#  player.conditional_investment_14     8.510417
#  player.conditional_investment_15     9.031250
#  player.conditional_investment_16     9.406250
#  player.conditional_investment_17     9.828125
#  player.conditional_investment_18    10.062500
#  player.conditional_investment_19    10.651042
# ...

# %% [markdown]
# ## Combine Strategy Method Analyzed and Strategy Method Instrucs & Comp Q App Data

# %%
sm_instrucs_df = sm_reading_and_cleaning('/Users/aaronberman/Desktop/DA_4_MGPGG/ToDate/StrategyMethodInstrucsCompQs_2023-09-26.csv')
sm_instrucs_df
# Out:
#      participant.id_in_session participant.code  participant.payoff  \
# 0                            1         znlu9jpg               841.0
# 1                            2         ntsf9cu5              1157.0
# 2                            3         4hnzonph              1210.0
# 3                            4         wye0azrj              1059.0
# 4                            5         zq928mn2              1049.0
# ..                         ...              ...                 ...
# 187                         12         r5gp08hr               624.0
# 188                         13         cbj3ehdm               991.0
# 189                         14         nle6hs8b               864.0
# 190                         15         nyszjmr9               860.0
# 191                         16         ztrzsad5               860.0
#
#      player.id_in_group  player.payoff  \
# 0                     1            0.0
# 1                     2            0.0
# ...

# %%
sm_merged = sm_merge_game_and_instrucs(smdf, sm_instrucs_df)
sm_merged
# Out:
#      participant.id_in_session participant.code  participant.payoff  \
# 0                            1         znlu9jpg               841.0
# 1                            2         ntsf9cu5              1157.0
# 2                            3         4hnzonph              1210.0
# 3                            4         wye0azrj              1059.0
# 4                            5         zq928mn2              1049.0
# ..                         ...              ...                 ...
# 187                         12         r5gp08hr               624.0
# 188                         13         cbj3ehdm               991.0
# 189                         14         nle6hs8b               864.0
# 190                         15         nyszjmr9               860.0
# 191                         16         ztrzsad5               860.0
#
#      player.id_in_group_sm  player.payoff_sm  player.unconditional_investment  \
# ...

# %%
sm_merged.to_csv('sm_merged.csv')

# %% [markdown]
# ### Pilot

# %%
"""smdf, all_sessions_player_type_dict, player_types_per_session_list, stat_test_dict, unconditional_dict, conditional_dict = strategy_method_analysis(
    '/Users/aaronberman/Desktop/DA_4_MGPGG/StrategyMethod_2023-07-05.csv', conditional_investment_x_values, conditional_investment_list, fgf_distribution, fgq_distrubtion,
    1)"""
# Out:
# "smdf, all_sessions_player_type_dict, player_types_per_session_list, stat_test_dict, unconditional_dict, conditional_dict = strategy_method_analysis(\n    '/Users/aaronberman/Desktop/DA_4_MGPGG/StrategyMethod_2023-07-05.csv', conditional_investment_x_values, conditional_investment_list, fgf_distribution, fgq_distrubtion,\n    1)"

# %%
#smdf

# %%
#all_sessions_player_type_dict

# %%
#player_types_per_session_list

# %%
#stat_test_dict

# %%
#unconditional_dict

# %%
#conditional_dict

# %% [markdown]
# ## Infographics

# %%
grid_shape = (12, 16)
figsize = (40, 40)

# %%
gen_sm_infographic(smdf, grid_shape, figsize, conditional_investment_list)
